# %% [markdown]
# ## **1. Load data**

# %%
import pandas as pd

# %% [markdown]
# ####**Enrollies' data:**

# %%
ggsheet = '1VCkHwBjJGRJ21asd9pxW4_0z2PWuKhbLR3gUHm-p4GI'
url='https://docs.google.com/spreadsheets/d/' + ggsheet + '/export?format=xlsx'
df = pd.read_excel(url, sheet_name='enrollies')

# %%
df.head(5)
# Out:
#    enrollee_id      full_name      city gender
# 0         8949     Mike Jones  city_103   Male
# 1        29725    Laura Jones   city_40   Male
# 2        11561   David Miller   city_21    NaN
# 3        33241    Laura Davis  city_115    NaN
# 4          666  Alex Martinez  city_162   Male

# %% [markdown]
# ####**Enrollies' education:**

# %%
url1 = 'https://assets.swisscoding.edu.vn/company_course/enrollies_education.xlsx'

df_education = pd.read_excel(url1, sheet_name='enrollies_education')

df_education.head(5)
# Out:
#    enrollee_id enrolled_university education_level major_discipline
# 0         8949       no_enrollment        Graduate             STEM
# 1        29725       no_enrollment        Graduate             STEM
# 2        11561    Full time course        Graduate             STEM
# 3        33241                 NaN        Graduate  Business Degree
# 4          666       no_enrollment         Masters             STEM

# %% [markdown]
# ####**Enrollies' working experience:**

# %%
url2 = 'https://assets.swisscoding.edu.vn/company_course/work_experience.csv'

df_exp = pd.read_csv(url2)

df_exp.head(5)
# Out:
#    enrollee_id      relevent_experience experience company_size  \
# 0         8949  Has relevent experience        >20          NaN
# 1        29725   No relevent experience         15        50-99
# 2        11561   No relevent experience          5          NaN
# 3        33241   No relevent experience         <1          NaN
# 4          666  Has relevent experience        >20        50-99
#
#      company_type last_new_job
# 0             NaN            1
# 1         Pvt Ltd           >4
# 2             NaN        never
# 3         Pvt Ltd        never
# 4  Funded Startup            4

# %% [markdown]
# ####**City development index:**

# %%
tables = pd.read_html( 'https://sca-programming-school.github.io/city_development_index/index.html')
df_city = tables[0]
df_city.sample(5)
# Out:
#          City  City Development Index
# 82     city_9                   0.743
# 85    city_84                   0.698
# 27    city_90                   0.698
# 116  city_180                   0.698
# 5    city_176                   0.764

# %% [markdown]
# ###**Data from SQL:**

# %%
from sqlalchemy import create_engine
# !pip install pymysql
import pymysql

# %% [markdown]
# ####**Training hours:**

# %%
Database type: MySQL
Host: 112.213.86.31
Port: 3360
Login: etl_practice
Password: 550814
Database name: company_course
Table name: training_hours
# Out:
#   File "/tmp/ipython-input-3409195155.py", line 1
#     Database type: MySQL
#              ^
# SyntaxError: invalid syntax

# %%
engine = create_engine('mysql+pymysql://etl_practice:550814@112.213.86.31:3360/company_course')

# %%
df_training_hours = pd.read_sql('training_hours', con=engine)
df_training_hours.sample(5)
# Out:
#        enrollee_id  training_hours
# 10918        16401               6
# 14749        18270              86
# 5846         15421              36
# 5649          9133              96
# 788          18892             166

# %% [markdown]
# ####**Employment:**

# %%
Database type: MySQL
Host: 112.213.86.31
Port: 3360
Login: etl_practice
Password: 550814
Database name: company_course
Table name: employment

# %%
df_employment = pd.read_sql('employment', con=engine)
df_employment.sample(5)
# Out:
#        enrollee_id  employed
# 4479          8021       1.0
# 16310        28565       0.0
# 9744         17261       0.0
# 17154        29997       1.0
# 8469         15029       0.0

# %% [markdown]
# ## **2. Cleaning Data**

# %% [markdown]
# *Check through all the dataframes*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   enrollee_id  19158 non-null  int64
#  1   full_name    19158 non-null  object
#  2   city         19158 non-null  object
#  3   gender       14650 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 598.8+ KB

# %%
df_education.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   enrollee_id          19158 non-null  int64
#  1   enrolled_university  18772 non-null  object
#  2   education_level      18698 non-null  object
#  3   major_discipline     16345 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 598.8+ KB

# %%
df_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   enrollee_id          19158 non-null  int64
#  1   relevent_experience  19158 non-null  object
#  2   experience           19093 non-null  object
#  3   company_size         13220 non-null  object
#  4   company_type         13018 non-null  object
#  5   last_new_job         18735 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 898.2+ KB

# %%
df_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   City                    123 non-null    object
#  1   City Development Index  123 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.1+ KB

# %%
df_training_hours.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   enrollee_id     19158 non-null  int64
#  1   training_hours  19158 non-null  int64
# dtypes: int64(2)
# memory usage: 299.5 KB

# %%
df_employment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   enrollee_id  19158 non-null  int64
#  1   employed     19158 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 299.5 KB

# %% [markdown]
# *Check duplicate*

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df.nunique())
# Out:
# enrollee_id    19158
# full_name        100
# city             123
# gender             3
# dtype: int64

# %%
df['gender'].unique()
# Out:
# array(['Male', nan, 'Female', 'Other'], dtype=object)

# %%
df_education.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df_education.nunique())
# Out:
# enrollee_id            19158
# enrolled_university        3
# education_level            5
# major_discipline           6
# dtype: int64

# %%
df_exp.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df_exp.nunique())
# Out:
# enrollee_id            19158
# relevent_experience        2
# experience                22
# company_size               8
# company_type               6
# last_new_job               6
# dtype: int64

# %%
df_city.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df_city.nunique())
# Out:
# City                      123
# City Development Index     93
# dtype: int64

# %%
df_training_hours.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df_training_hours.nunique())
# Out:
# enrollee_id       19158
# training_hours      241
# dtype: int64

# %%
df_employment.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df_employment.nunique())
# Out:
# enrollee_id    19158
# employed           2
# dtype: int64

# %% [markdown]
# *Fill NA data*

# %%
df['gender'] = df['gender'].fillna("Unknown")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   enrollee_id  19158 non-null  int64
#  1   full_name    19158 non-null  object
#  2   city         19158 non-null  object
#  3   gender       19158 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 598.8+ KB

# %%
df.sample(5)
# Out:
#        enrollee_id        full_name      city   gender
# 1195          8978      Sarah Smith   city_75  Unknown
# 12592        12827      Laura Brown  city_136     Male
# 13859         4186    Emily Johnson  city_103     Male
# 8320          4023   John Hernandez  city_103     Male
# 15568        32983  Katie Hernandez  city_160     Male

# %%
df_education = df_education.fillna("Unknown")
df_education.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   enrollee_id          19158 non-null  int64
#  1   enrolled_university  19158 non-null  object
#  2   education_level      19158 non-null  object
#  3   major_discipline     19158 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 598.8+ KB

# %%
df_education.sample(5)
# Out:
#        enrollee_id enrolled_university education_level major_discipline
# 2888         28743       no_enrollment     High School          Unknown
# 15268        23471       no_enrollment        Graduate             STEM
# 2864         19529       no_enrollment        Graduate             STEM
# 619          12349       no_enrollment        Graduate             STEM
# 13857         2949       no_enrollment         Masters             STEM

# %%
df_exp = df_exp.fillna("Unknown")
df_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   enrollee_id          19158 non-null  int64
#  1   relevent_experience  19158 non-null  object
#  2   experience           19158 non-null  object
#  3   company_size         19158 non-null  object
#  4   company_type         19158 non-null  object
#  5   last_new_job         19158 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 898.2+ KB

# %%
df_exp.sample(5)
# Out:
#       enrollee_id      relevent_experience experience company_size  \
# 6469        18765  Has relevent experience         10      100-500
# 1642        23083  Has relevent experience         10        50-99
# 1901         4657  Has relevent experience        >20      Unknown
# 3999        27511  Has relevent experience        >20      Unknown
# 2402         4592   No relevent experience          2      Unknown
#
#      company_type last_new_job
# 6469      Pvt Ltd            2
# 1642      Unknown            3
# 1901      Unknown        never
# 3999      Unknown           >4
# 2402      Unknown      Unknown
